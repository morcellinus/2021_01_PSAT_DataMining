# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/Shareddrives/21-01 데마팀 화이팅/데이터셋/최종전처리데이터셋.csv", encoding = 'CP949')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1168 non-null   int64
#  1   V1              1168 non-null   int64
#  2   name_kor_x      1168 non-null   object
#  3   name_eng        1167 non-null   object
#  4   producer_kor_x  1159 non-null   object
#  5   producer_eng_x  1167 non-null   object
#  6   region_kor      1168 non-null   object
#  7   region_eng      1168 non-null   object
#  8   style_kor       1168 non-null   object
#  9   style_eng       1168 non-null   object
#  10  apv             1165 non-null   float64
#  11  ibu             1148 non-null   float64
#  12  price           949 non-null    float64
#  13  종류              857 non-null    object
#  14  info            1147 non-null   object
#  15  review_eng      930 non-null    object
#  16  mean_average    993 non-null    object
# ...

# %%
Ale = data[data['종류'] == '에일']
Ale.reset_index(inplace=True)

# %%
Ale_review = Ale[['review_eng']]
Ale_review['review_eng'][0:10]
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    [['Review: 0,5l can of Steam Brew Imperial IPA...
# 4    [['Dark copper colour with white head. Aroma o...
# 5                                                  NaN
# 6                                                  NaN
# 7    [['On tap at Di Napoli - Maestri Pizzaioli, Tr...
# 8    [['Appearance is a moderately hazy pale amber ...
# 9    [['330ml bottle. Clear reddish brown, brief fi...
# Name: review_eng, dtype: object

# %%
import re
Ale_review['review_eng'] = Ale_review['review_eng'].map(lambda x: re.sub('[,\'.[!?]', '', str(x)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Ale_review['review_eng']
# Out:
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3      Review: 05l can of Steam Brew Imperial IPA: 78...
# 4      Dark copper colour with white head Aroma of ho...
#                              ...
# 483                                                  nan
# 484                                                  nan
# 485                                                  nan
# 486                                                  nan
# 487                                                  nan
# Name: review_eng, Length: 488, dtype: object

# %%
import nltk
nltk.download('punkt')
Ale_review['review_eng'] = Ale_review.apply(lambda row:nltk.word_tokenize(row['review_eng']), axis = 1)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(Ale_review.head(30))
# Out:
#                                            review_eng
# 0                                               [nan]
# 1                                               [nan]
# 2                                               [nan]
# 3   [Review, :, 05l, can, of, Steam, Brew, Imperia...
# 4   [Dark, copper, colour, with, white, head, Arom...
# 5                                               [nan]
# 6                                               [nan]
# 7   [On, tap, at, Di, Napoli, -, Maestri, Pizzaiol...
# 8   [Appearance, is, a, moderately, hazy, pale, am...
# 9   l, bottle, Clear, reddish, brown, brief, ...
# 10  [A, Witbier, thats, well, balanced, between, i...
# 11  [Clear, dark, golden, wit, a, good, white, mou...
# 12                                              [nan]
# 13                                              [nan]
# 14                                              [nan]
# 15                                              [nan]
# ...

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
Ale_review['review_eng'] = Ale_review['review_eng'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x])
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
tokenized_doc = Ale_review['review_eng'].apply(lambda x: [word for word in x if len(word) > 3])
print(tokenized_doc[:30])
# Out:
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [Review, Steam, Brew, Imperial, Love, Steam, B...
# 4     [Dark, copper, colour, with, white, head, Arom...
# 5                                                    []
# 6                                                    []
# 7     [Napoli, Maestri, Pizzaioli, Trieste, Hazy, or...
# 8     [Appearance, moderately, hazy, pale, amber, wi...
# 9     l, bottle, Clear, reddish, brown, brief, ...
# 10    [Witbier, thats, well, balance, between, fruit...
# 11    [Clear, dark, golden, good, white, mousse-like...
# 12                                                   []
# 13                                                   []
# 14                                                   []
# 15                                                   []
# 16    [Clear, light, gold, good, carbonation, inch, ...
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
stop_words = stopwords.words('english')
stop_words.extend(['bottle', 'can', 'finish', 'good', 'nice', 'ok', 'like', 'Good'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokens_pos = []
for i in range(len(tokenized_doc)):
  a = nltk.pos_tag(tokenized_doc[i])
  mini = []
  for word, pos in a:
    if 'JJ' in pos and word not in stop_words:
      mini.append(word)
      # tokens_pos.append((word,'JJ'))
  tokens_pos.append(mini)
print(tokens_pos)
# Out:
# [[], [], [], ['full', 'exact', 'rusty', 'catch', 'gear', 'pour', 'alive', 'creamy', 'white', 'colour', 'fantastic', 'delicious', 'strong', 'rich', 'tropical', 'typical', 'straight', 'powerful', 'nose', 'hoppy', 'deep', 'manageable', 'prominent', 'heavy', 'didnt', 'strong', 'sessionable', 'alive', 'Yellow', 'much', 'fantastic', 'decent', 'bitter', 'solid', 'white', 'floral', 'bitter', 'sweeter', 'golden', 'finger', 'white', 'foamy', 'nose', 'black', 'cheap', 'stronger', 'pleasant', 'simular', 'drinkable', 'gear', 'true', 'tropical', 'clear', 'golden', 'smaller', 'soft', 'small', 'white', 'needle', 'soft', 'smooth', 'colour', 'pale-brown', 'unclear', 'thin', 'bitter'], ['white', 'floral', 'herbal', 'med-high', 'moderate', 'hoppy', 'grainy', 'overall', 'honeyish', 'drinkable', 'average', 'long', 'last', 'clear', 'dark', 'brown', 'sweet', 'Clear', 'small', 'off-white', 'rusty', 'frothy', 'malt', 'vegetal', 'bitter', 'sweet', 'bitter', 'thick', 'easy', 'best', 'Clear', 'grainy', 'alcoholi
# ...

# %%
detokenized_doc = []
for i in range(len(Ale_review)):
    t = ' '.join(tokens_pos[i])
    detokenized_doc.append(t)

Ale_review['review_eng'] = detokenized_doc
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words=stop_words, 
max_features= 1000) # 상위 1,000개의 단어를 보존 
X = vectorizer.fit_transform(Ale_review['review_eng'])
X.shape # TF-IDF 행렬의 크기 확인
# Out:
# (488, 1000)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,learning_method='online',random_state=777,max_iter=1)

# %%
lda_top=lda_model.fit_transform(X)

# %%
print(lda_model.components_)
print(lda_model.components_.shape)
# Out:
# [[0.73781079 0.71153089 0.80248951 ... 0.62082398 2.45708528 0.92556618]
#  [0.43984743 0.50377696 0.50081617 ... 0.53916088 0.77655016 0.53439719]
#  [0.49792553 0.63659544 0.50886283 ... 0.51118299 0.6563029  0.6618691 ]
#  ...
#  [0.58338401 0.52256945 0.52257988 ... 0.5563532  0.66268579 0.48603755]
#  [0.52263436 0.49025953 0.57725642 ... 0.55437667 0.76167325 0.49866777]
#  [0.4885821  0.55537785 0.54441125 ... 0.49283411 0.59197748 0.47314564]]
# (10, 1000)

# %%
terms = vectorizer.get_feature_names() # 단어 집합. 1,000개의 단어가 저장됨.

def get_topics(components, feature_names, n=3):
    for idx, topic in enumerate(components):
        print("Topic %d:" % (idx+1), [(feature_names[i], topic[i].round(2)) for i in topic.argsort()[:-n - 1:-1]])
get_topics(lda_model.components_,terms)
# Out:
# Topic 1: [('white', 26.42), ('bitter', 14.8), ('light', 14.35)]
# Topic 2: [('sour', 1.78), ('white', 1.42), ('tropical', 1.15)]
# Topic 3: [('white', 2.38), ('dark', 2.12), ('bitter', 1.75)]
# Topic 4: [('white', 0.96), ('zest', 0.82), ('golden', 0.81)]
# Topic 5: [('white', 1.33), ('thin', 1.11), ('bitter', 0.99)]
# Topic 6: [('white', 1.13), ('golden', 0.89), ('sweetish', 0.77)]
# Topic 7: [('cheap', 0.79), ('upfront', 0.72), ('golden', 0.72)]
# Topic 8: [('sour', 2.25), ('white', 1.54), ('little', 1.45)]
# Topic 9: [('white', 1.34), ('belgian', 1.11), ('black', 1.05)]
# Topic 10: [('white', 1.45), ('sour', 1.22), ('tropical', 1.16)]

# %%
from gensim import corpora
dictionary = corpora.Dictionary(tokens_pos)
corpus = [dictionary.doc2bow(text) for text in tokens_pos]

# %%
import gensim
NUM_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word = dictionary, passes =15)
topics = ldamodel.print_topics(num_words = 7)

for topic in topics:
  print(topic)
# Out:
# (0, '0.044*"white" + 0.033*"bitter" + 0.024*"sweet" + 0.024*"hoppy" + 0.023*"golden" + 0.019*"strong" + 0.019*"light"')
# (1, '0.070*"white" + 0.032*"light" + 0.030*"golden" + 0.029*"bitter" + 0.023*"sweet" + 0.019*"sour" + 0.017*"tropical"')
# (2, '0.035*"dark" + 0.030*"brown" + 0.021*"sweet" + 0.020*"sour" + 0.018*"light" + 0.011*"black" + 0.011*"beige"')

# %%
! pip install pyLDAvis

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
vis = gensimvis.prepare(ldamodel, corpus, dictionary)

# %%
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3931398106162316329903994239"></div>
# <script type="text/javascript">
#
# ...
